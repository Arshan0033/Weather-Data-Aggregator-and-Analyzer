# %% [markdown]
# ## Arshan shaikh

# %%
import pandas as pd
import numpy as np
import requests
import streamlit as st
import requests
import json

# %% [markdown]
# # we have take the API key from OpenWeatherMap to fache the data API .

# %%
# Your API key (from OpenWeatherMap or any other service)
api_key =  '44deb408648c2ccb6a668f5aee7f0709'
# Define the city or coordinates (latitude and longitude) for which you want to fetch the weather
city = "Pune"
url = f"http://api.openweathermap.org/data/2.5/forecast?q={city}&appid={api_key}&units=metric"
response = requests.get(url)
if response.status_code == 200:
    data = response.json()  # Parse the JSON data
    print(json.dumps(data, indent=4))  # Print the data in a readable format
    for forecast in data['list']:
     time = forecast['dt_txt']
     temp = forecast['main']['temp']
     description = forecast['weather'][0]['description']
     print(f"At {time}, the temperature will be {temp}°C with {description}.")
else:
    print(f"Error: Unable to fetch data (Status Code: {response.status_code})")
# Out:
# {
#     "cod": "200",
#     "message": 0,
#     "cnt": 40,
#     "list": [
#         {
#             "dt": 1726930800,
#             "main": {
#                 "temp": 27.54,
#                 "feels_like": 30.73,
#                 "temp_min": 23.76,
#                 "temp_max": 27.54,
#                 "pressure": 1010,
#                 "sea_level": 1010,
#                 "grnd_level": 937,
#                 "humidity": 78,
#                 "temp_kf": 3.78
#             },
#             "weather": [
#                 {
#                     "id": 501,
#                     "main": "Rain",
#                     "description": "moderate rain",
#                     "icon": "10n"
#                 }
#             ],
#             "clouds": {
#                 "all": 76
#             },
#             "wind": {
#                 "speed": 3.24,
#                 "deg": 262,
#                 "gust": 4.65
#             },
#             "visibility": 10000,
#             "pop": 1,
# ...

# %%
response
# Out:
# <Response [200]>

# %%
data
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1726920000,
#    'main': {'temp': 31.43,
#     'feels_like': 36.05,
#     'temp_min': 26.78,
#     'temp_max': 31.43,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 946,
#     'humidity': 61,
#     'temp_kf': 4.65},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 69},
#    'wind': {'speed': 4.61, 'deg': 285, 'gust': 5.5},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 1.08},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2024-09-21 12:00:00'},
#   {'dt': 1726930800,
#    'main': {'temp': 28.8,
#     'feels_like': 32.47,
#     'temp_min': 23.54,
#     'temp_max': 28.8,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 948,
#     'humidity': 71,
#     'temp_kf': 5.26},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
# ...

# %%
data['list'][1]['dt']
# Out:
# 1726930800

# %%
len(data['list'])
# Out:
# 40

# %%
# we have take the time column from the data base .
time=[]
for i in range(0,39):
    time.append(data['list'][i]['dt'])

# %%
time=pd.Series(time)

# %%
data['list'][1]['main']['humidity']
# Out:
# 71

# %%
# we have take the humidity column data from the data base 
hum=[]
for i in range(0,39):
    hum.append(data['list'][i]['main']['humidity'])
hum
# Out:
# [78,
#  83,
#  89,
#  95,
#  83,
#  61,
#  53,
#  72,
#  89,
#  94,
#  95,
#  95,
#  84,
#  67,
#  70,
#  80,
#  93,
#  94,
#  95,
#  95,
#  88,
#  84,
#  87,
#  90,
#  94,
#  96,
#  97,
#  97,
#  94,
#  91,
#  93,
#  95,
#  96,
#  95,
#  94,
#  94,
#  94,
#  93,
#  95]

# %%
hum=pd.Series(hum)

# %%
df=pd.DataFrame({
    'time':time,
    'humidity':hum
})
df.head()
# Out:
#          time  humidity
# 0  1726920000        61
# 1  1726930800        71
# 2  1726941600        83
# 3  1726952400        94
# 4  1726963200        95

# %%
df.tail()
# Out:
#           time  humidity
# 34  1727287200        95
# 35  1727298000        96
# 36  1727308800        96
# 37  1727319600        94
# 38  1727330400        94

# %%
data['list'][0]['dt_txt']
# Out:
# '2024-09-21 12:00:00'

# %%
# we have take the date column data from the data base .
date=[]
for i in range(0,39):
    date.append(data['list'][i]['dt_txt'])

# %%
date[0][0:10]
# Out:
# '2024-09-21'

# %%
d1=[]
for i in date:
    d1.append(i[0:10])

# %%
d1=pd.Series(d1)
d1
# Out:
# 0     2024-09-21
# 1     2024-09-21
# 2     2024-09-21
# 3     2024-09-21
# 4     2024-09-22
# 5     2024-09-22
# 6     2024-09-22
# 7     2024-09-22
# 8     2024-09-22
# 9     2024-09-22
# 10    2024-09-22
# 11    2024-09-22
# 12    2024-09-23
# 13    2024-09-23
# 14    2024-09-23
# 15    2024-09-23
# 16    2024-09-23
# 17    2024-09-23
# 18    2024-09-23
# 19    2024-09-23
# 20    2024-09-24
# 21    2024-09-24
# 22    2024-09-24
# 23    2024-09-24
# 24    2024-09-24
# 25    2024-09-24
# 26    2024-09-24
# 27    2024-09-24
# 28    2024-09-25
# 29    2024-09-25
# 30    2024-09-25
# 31    2024-09-25
# 32    2024-09-25
# 33    2024-09-25
# 34    2024-09-25
# 35    2024-09-25
# 36    2024-09-26
# 37    2024-09-26
# 38    2024-09-26
# dtype: object

# %%
df = pd.DataFrame({
    'Time': time,
    'Humidity': hum,
    'date':d1
})
df.head()
# Out:
#          Time  Humidity        date
# 0  1726920000        61  2024-09-21
# 1  1726930800        71  2024-09-21
# 2  1726941600        83  2024-09-21
# 3  1726952400        94  2024-09-21
# 4  1726963200        95  2024-09-22

# %%
#df.to_csv("Weather files.csv",index=False) ----- is ko end me run karna hai

# %%
# cheakin data type of all columns
print(df.dtypes)
# Out:
# Time         int64
# Humidity     int64
# date        object
# dtype: object

# %%
# we are changing the data type of date columns .
df['date']=pd.to_datetime(df['date'])

# %%
df['date.']=df['date'].astype('int64')//10**9

# %%
df.head()
# Out:
#          Time  Humidity       date       date.
# 0  1726920000        61 2024-09-21  1726876800
# 1  1726930800        71 2024-09-21  1726876800
# 2  1726941600        83 2024-09-21  1726876800
# 3  1726952400        94 2024-09-21  1726876800
# 4  1726963200        95 2024-09-22  1726963200

# %%
# we are taking the temp column from data base .
data['list'][1]['main']['temp']
# Out:
# 28.8

# %%
tem=[]
for i in range(0,39):
    tem.append(data['list'][i]['main']['temp'])

# %%
# converting  temp column series to DataFrame .
t1=pd.Series(tem)
t2=pd.DataFrame(t1)
t2.head()
# Out:
#        0
# 0  31.43
# 1  28.80
# 2  25.69
# 3  22.26
# 4  21.68

# %%
# converting all seperate column togather.
df = pd.DataFrame({
    'Time': time,
    'Humidity': hum,
    'date':d1,
    'temperature':t1
})
df.head()
# Out:
#          Time  Humidity        date  temperature
# 0  1726920000        61  2024-09-21        31.43
# 1  1726930800        71  2024-09-21        28.80
# 2  1726941600        83  2024-09-21        25.69
# 3  1726952400        94  2024-09-21        22.26
# 4  1726963200        95  2024-09-22        21.68

# %%
# saving data to csv file .
df.to_csv("Weather_files.csv",index=False)

# %%
df.head()
# Out:
#          Time  Humidity        date  temperature
# 0  1726920000        61  2024-09-21        31.43
# 1  1726930800        71  2024-09-21        28.80
# 2  1726941600        83  2024-09-21        25.69
# 3  1726952400        94  2024-09-21        22.26
# 4  1726963200        95  2024-09-22        21.68

# %%
# faching data from MYSQL for visulize the data .
import mysql.connector as sql
import pandas as pd
data_co=sql.connect(host='localhost',database='weather_data1',
user='root',password='ARSHAN0987654321')
df1=pd.read_sql('select * from weather_files',con=data_co)
# Out:
# C:\Users\shaik\AppData\Local\Temp\ipykernel_19900\1316010668.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df1=pd.read_sql('select * from weather_files',con=data_co)

# %%
df1.head()
# Out:
#          Time  Humidity        date  temperature
# 0  1726920000        61  2024-09-21        31.43
# 1  1726930800        71  2024-09-21        28.80
# 2  1726941600        83  2024-09-21        25.69
# 3  1726952400        94  2024-09-21        22.26
# 4  1726963200        95  2024-09-22        21.68

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# this graph show the day by day humidity is increasing and Decreasing .
sns.lineplot(x='date',y='Humidity',data=df)
# Out:
# C:\Users\shaik\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\shaik\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='date', ylabel='Humidity'>

# %%
# this graph show the day by day temperature is increasing and Decreasing .
sns.lineplot(x='date',y='temperature',data=df)
# Out:
# C:\Users\shaik\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\shaik\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='date', ylabel='temperature'>

# %%
# we are cheaking the humidity for analysis this graph .
plt.figure(figsize=(15,5))
sns.barplot(y='Humidity',x='date',data=df)
# Out:
# <Axes: xlabel='date', ylabel='Humidity'>

# %%
# checking the humidity for this graph .
plt.figure(figsize=(9,5))
sns.countplot(x='Humidity',data=df)
# Out:
# <Axes: xlabel='Humidity', ylabel='count'>

# %%
# this graph shows the temperature of day by day .
plt.figure(figsize=(15,5))
sns.barplot(y='temperature',x='date',data=df)
# Out:
# <Axes: xlabel='date', ylabel='temperature'>

# %%
# this graph was showing the humidity with temperature .
H = df['Humidity'].value_counts().head(10)
labels =['29.51','25.99','22.82','22.26','21.68','24.14','28.41','28.64','26.79','23.78']
plt.figure(figsize=(10, 10))
plt.pie(H,labels=labels,autopct='%2.1f%%', startangle=90)
plt.show()
